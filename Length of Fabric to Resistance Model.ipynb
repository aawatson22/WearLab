# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Test 1':  [1807, 1411, 1111, 833, 781, 696, 641, 577, 529],
    'Test 2':  [2100, 1617, 1210, 834, 750, 651, 628, 581, 491],
    'Test 3':  [1981, 1449, 1189, 876, 742, 693, 635, 585, 494],
    'Test 4':  [1805, 1503, 1095, 901, 791, 685, 628, 579, 490],
    'Test 5':  [1700, 1536, 1183, 902, 728, 680, 643, 565, 486],
    'Test 6':  [1705, 1492, 1043, 926, 796, 676, 652, 565, 494],
    'Test 7':  [1906, 1593, 1192, 859, 726, 670, 631, 575, 482],
    'Test 8':  [1900, 1601, 1043, 853, 744, 666, 628, 572, 490],
    'Test 9':  [1804, 1412, 1192, 898, 723, 682, 626, 560, 499],
    'Test 10': [1795, 1448, 1043, 888, 718, 672, 627, 556, 480]
    }, index=  [0.0,   0.5,  1.0, 1.5, 2.0, 2.5, 3.0, 3.5, 4.0 ])
lines = df.plot.line()
lines.set_xlabel("Distance Stretched (in)")
lines.set_ylabel("Resistance (kΩ)")
lines.set_xticks(df.index)
lines.set_title("Fabric Resistance to Stretch Distance")
lines.get_legend().remove()

lines.figure.savefig('FabricResistance.eps', format='eps', dpi=1000)
